# %%
# Install library yang dibutuhkan
# pip install nltk
# pip install Sastrawi
# pip install stanza
# pip install streamlit

import numpy as np
import pandas as pd
import re
import stanza
import nltk
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# Set random seed
np.random.seed(42)

# Download data nltk
nltk.download('stopwords')
nltk.download('omw-1.4')

# Inisialisasi stopwords, stemmer, dan lemmatizer
stop_words = set(stopwords.words('indonesian'))
factory = StemmerFactory()
stemmer = factory.create_stemmer()
# Inisialisasi stanza untuk lemmatization
stanza.download('id')
nlp = stanza.Pipeline('id')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json: 392kB [00:00, 32.9MB/s]
# 2024-10-13 10:11:32 INFO: Downloaded file to C:\Users\ACER\stanza_resources\resources.json
# 2024-10-13 10:11:32 INFO: Downloading default packages for language: id (Indonesian) ...
# 2024-10-13 10:11:34 INFO: File exists: C:\Users\ACER\stanza_resources\id\default.zip
# 2024-10-13 10:11:38 INFO: Finished downloading models and saved to C:\Users\ACER\stanza_resources
# 2024-10-13 10:11:38 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json: 392kB [00:00, 11.1MB/s]
# 2024-10-13 10:11:38 INFO: Downloaded file to C:\Users\ACER\stanza_resources\resources.json
# 2024-10-13 10:11:40 INFO: Loading these models for language: id (Indonesian):
# ===============================
# | Processor    | Package      |
# -------------------------------
# | tokenize     | gsd          |
# | mwt          | gsd          |
# | pos          | gsd_charlm   |
# | lemma        | gsd_nocharlm |
# | constituency | icon_charlm  |
# | depparse     | gsd_charlm   |
# ===============================
#
# 2024-10-13 10:11:40 INFO: Using device: cpu
# 2024-10-13 10:11:40 INFO: Loading: tokenize
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\tokenization\trainer.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-10-13 10:11:50 INFO: Loading: mwt
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\mwt\trainer.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-10-13 10:11:50 INFO: Loading: pos
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\pos\trainer.py:139: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\common\pretrain.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(self.filename, lambda storage, loc: storage)
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\common\char_model.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(filename, lambda storage, loc: storage)
# 2024-10-13 10:11:50 INFO: Loading: lemma
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\lemma\trainer.py:239: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-10-13 10:11:51 INFO: Loading: constituency
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\constituency\base_trainer.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-10-13 10:11:51 INFO: Loading: depparse
# C:\Users\ACER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stanza\models\depparse\trainer.py:194: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-10-13 10:11:51 INFO: Done loading processors!

# %% [markdown]
# UI Dengan Streamlit

# %%
# Install library yang dibutuhkan
# Buat file app.py di dalam jupyter notebook
# eksekusi streamlit dengan aktivasi enviroment tempat streamlit diinstall (.venv\Scripts\python -m streamlit run app_vsm.py)

# %%writefile app_vsm.py
import streamlit as st
import string
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean
import re
import nltk
import stanza
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Download NLTK data
nltk.download('stopwords')
nltk.download('omw-1.4')

# Initialize stopwords, stemmer, and lemmatizer
stop_words = set(stopwords.words('indonesian'))
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stanza.download('id')
nlp = stanza.Pipeline('id')

# Preprocessing functions
def case_folding(text):
    text = text.lower()
    return re.sub(r'[^\w\s]', '', text)

def tokenize(text):
    return text.split()

def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

def stemming(tokens):
    return [stemmer.stem(word) for word in tokens]

def lemmatization(tokens):
    text = ' '.join(tokens)
    doc = nlp(text)
    return [word.lemma for sent in doc.sentences for word in sent.words]

def preprocess_with_stemming(text):
    text = case_folding(text)
    tokens = tokenize(text)
    tokens = remove_stopwords(tokens)
    tokens = stemming(tokens)
    return ' '.join(tokens)

def preprocess_with_lemmatization(text):
    text = case_folding(text)
    tokens = tokenize(text)
    tokens = remove_stopwords(tokens)
    tokens = lemmatization(tokens)
    return ' '.join(tokens)

# TF-IDF functions
def tfidf_with_stemming(documents):
    preprocessed_documents = [preprocess_with_stemming(doc) for doc in documents]
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(preprocessed_documents)
    return tfidf_matrix, vectorizer

def tfidf_with_lemmatization(documents):
    preprocessed_documents = [preprocess_with_lemmatization(doc) for doc in documents]
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(preprocessed_documents)
    return tfidf_matrix, vectorizer

# TF and IDF computation functions
def compute_tf(documents, tf_type):
    tf_matrix = []
    for doc in documents:
        tokens = preprocess_with_lemmatization(doc)
        token_counts = pd.Series(tokens.split()).value_counts()

        if tf_type == 'binary':
            tf_vector = (token_counts > 0).astype(int)
        elif tf_type == 'raw_frequency':
            tf_vector = token_counts
        elif tf_type == 'log_normalization':
            tf_vector = 1 + np.log(token_counts)
        elif tf_type == 'double_normalization_0.5':
            max_count = token_counts.max()
            tf_vector = 0.5 + 0.5 * (token_counts / max_count)
        elif tf_type == 'double_normalization_K':
            K = 0.5
            max_count = token_counts.max()
            tf_vector = K + (1 - K) * (token_counts / max_count)

        tf_matrix.append(tf_vector)

    return pd.DataFrame(tf_matrix).fillna(0).T

def compute_idf(documents, idf_type):
    N = len(documents)
    token_df = pd.Series(' '.join(preprocess_with_lemmatization(doc) for doc in documents).split()).value_counts()

    if idf_type == 'unary':
        idf_vector = pd.Series(1, index=token_df.index)
    elif idf_type == 'inverse_frequency':
        idf_vector = np.log(N / token_df)
    elif idf_type == 'inv_frequency_smooth':
        idf_vector = np.log(1 + (N / token_df))
    elif idf_type == 'inv_frequency_max':
        max_df = token_df.max()
        idf_vector = np.log(1 + (max_df / token_df))
    elif idf_type == 'probabilistic_inv_frequency':
        idf_vector = np.log((N - token_df) / token_df)

    return idf_vector

def compute_tf_idf(documents, tf_type, idf_type):
    tf_matrix = compute_tf(documents, tf_type)
    idf_vector = compute_idf(documents, idf_type)
    tf_idf_matrix = tf_matrix.multiply(idf_vector, axis=0)
    return tf_idf_matrix

# Search function
def search_documents(documents, query, tf_type, idf_type, similarity_metric):
    tf_idf_matrix = compute_tf_idf(documents, tf_type, idf_type)
    
    preprocessed_query = preprocess_with_lemmatization(query)
    query_tf = pd.Series(preprocessed_query.split()).value_counts()
    query_tf_vector = pd.Series(query_tf).reindex(tf_idf_matrix.index, fill_value=0)

    if similarity_metric == 'cosine':
        similarities = cosine_similarity(query_tf_vector.values.reshape(1, -1), tf_idf_matrix.T).flatten()
    elif similarity_metric == 'euclidean':
        similarities = np.array([euclidean(query_tf_vector, doc_vector) for doc_vector in tf_idf_matrix.T.to_numpy()])
        similarities = 1 / (1 + similarities)  # Convert to similarity score (higher is better)
    
    ranked_indices = np.argsort(similarities)[::-1]
    return ranked_indices, similarities

# Streamlit app
def main():
    st.title("Vector Space Model Document Search")
    
    # Input for documents
    documents = st.text_area("Enter your documents (one per line):", height=200)
    documents = documents.split('\n')
    
    # Input for query
    query = st.text_input("Enter your search query:")
    
    # Select TF type
    tf_type = st.selectbox(
        "Select Term Frequency (TF) type:",
        ['binary', 'raw_frequency', 'log_normalization', 'double_normalization_0.5', 'double_normalization_K']
    )
    
    # Select IDF type
    idf_type = st.selectbox(
        "Select Inverse Document Frequency (IDF) type:",
        ['unary', 'inverse_frequency', 'inv_frequency_smooth', 'inv_frequency_max', 'probabilistic_inv_frequency']
    )
    
    # Select similarity metric
    similarity_metric = st.radio("Select similarity metric:", ["Cosine Similarity", "Euclidean Distance"])
    
    if st.button("Search"):
        if documents and query:
            ranked_indices, similarities = search_documents(
                documents, 
                query, 
                tf_type, 
                idf_type, 
                'cosine' if similarity_metric == "Cosine Similarity" else 'euclidean'
            )
            
            st.subheader("Search Results:")
            for i, idx in enumerate(ranked_indices[:10]):  # Display top 10 results
                score = similarities[idx]
                st.write(f"{i+1}. ({similarity_metric}: {score:.4f}) {documents[idx]}")
        else:
            st.warning("Please enter both documents and a search query.")
    
    # Preprocessing demonstration
    if st.checkbox("Show Preprocessing Results"):
        st.subheader("Preprocessing Results:")
        for doc in documents:
            original_text = case_folding(doc)
            tokens = tokenize(original_text)
            tokens_no_stopwords = remove_stopwords(tokens)
            stemmed_result = stemming(tokens_no_stopwords)
            lemmatized_result = lemmatization(tokens_no_stopwords)
            
            st.write(f"Original: {original_text}")
            st.write(f"Stemming: {' '.join(stemmed_result)}")
            st.write(f"Lemmatization: {' '.join(lemmatized_result)}")
            st.write("\n")

if __name__ == "__main__":
    main()
# Out:
# Overwriting app_vsm.py

# %% [markdown]
# LOAD DATA

# %%
documents = [
    "Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.",
    "Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.",
    "Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.",
    "Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.",
    "Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.",
    "Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.",
    "Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.",
    "Perpustakaan digital memudahkan akses informasi bagi semua kalangan.",
    "Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.",
    "Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.",
    "Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.",
    "Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.",
    "Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.",
    "Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.",
    "Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.",
    "Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.",
    "Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.",
    "Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.",
    "Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.",
    "Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat."
]

# %% [markdown]
# PREPROCESSING TEXT

# %%
# Step 1: Case folding and cleaning (used in all scenarios)
def case_folding(text):
    text = text.lower()
    return re.sub(r'[^\w\s]', '', text)

# Step 2: Tokenization
def tokenize(text):
    return text.split()

# Step 3: Stopwords removal
def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

# Step 4: Stemming
def stemming(tokens):
    return [stemmer.stem(word) for word in tokens]

# Step 5: Lemmatization using stanza
def lemmatization(tokens):
    text = ' '.join(tokens)  # Gabungkan token menjadi teks untuk diproses
    doc = nlp(text)
    return [word.lemma for sent in doc.sentences for word in sent.words]

# %%
# Preprocessing with stemming
def preprocess_with_stemming(text):
    text = case_folding(text)
    tokens = tokenize(text)
    tokens = remove_stopwords(tokens)
    tokens = stemming(tokens)
    return ' '.join(tokens)

# %%
# Preprocessing with lemmatization
def preprocess_with_lemmatization(text):
    text = case_folding(text)
    tokens = tokenize(text)
    tokens = remove_stopwords(tokens)
    tokens = lemmatization(tokens)
    return ' '.join(tokens)

# %%
# Menerapkan preprocessing pada setiap dokumen
print("Hasil Preprocessing dengan Stemming dan Lemmatization:")
for doc in documents:
    # Proses case folding
    original_text = case_folding(doc)

    # Tokenisasi
    tokens = tokenize(original_text)

    # Stopwords removal
    tokens_no_stopwords = remove_stopwords(tokens)

    # Proses stemming
    stemmed_result = stemming(tokens_no_stopwords)

    # Proses lemmatization
    lemmatized_result = lemmatization(tokens_no_stopwords)

    # Menampilkan hasil
    print(f"Original: {original_text}")
    print(f"Stemming: {' '.join(stemmed_result)}")
    print(f"Lemmatization: {' '.join(lemmatized_result)}")
    print("\n")
# Out:
# Hasil Preprocessing dengan Stemming dan Lemmatization:
# Original: perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi
# Stemming: pustaka ajar informasi
# Lemmatization: perpustakaan belajar informasi
#
#
# Original: membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda
# Stemming: baca buku pustaka alam ajar beda
# Lemmatization: baca buku perpustakaan pengalaman belajar beda
#
#
# Original: kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar
# Stemming: kalang mahasiswa unjung pustaka ajar
# Lemmatization: kalangan mahasiswa kunjung perpustakaan belajar
#
#
# Original: koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu
# Stemming: koleksi buku pustaka agam cakup disiplin ilmu
# Lemmatization: koleksi buku perpustakaan ragam cakup disiplin ilmu
#
#
# Original: belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan
# Stemming: ajar mandiri manfaat sumber daya pustaka
# Lemmatization: belajar mandiri manfaat sumber daya perpustakaan
#
#
# Original: perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar
# Stemming: pustaka sedia fasilitas dukung proses ajar
# Lemmatization: perpustakaan sedia fasilitas dukung proses belajar
#
#
# Original: kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar
# Stemming: kalang ajar sekolah pustaka ajar
# Lemmatization: kalangan pelajar sekolah perpustakaan belajar
#
#
# Original: perpustakaan digital memudahkan akses informasi bagi semua kalangan
# Stemming: pustaka digital mudah akses informasi kalang
# Lemmatization: perpustakaan digital mudah akses informasi kalangan
#
#
# Original: belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi
# Stemming: ajar kelompok pustaka tingkat paham materi
# Lemmatization: belajar kelompok perpustakaan tingkat paham materi
#
#
# Original: perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat
# Stemming: pustaka ada acara tingkat minat baca kalang masyarakat
# Lemmatization: perpustakaan ada acara tingkat minat baca kalangan masyarakat
#
#
# Original: pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar
# Stemming: pustakawan peran bantu unjung cari informasi ajar
# Lemmatization: pustakawan peran bantu kunjung cari informasi belajar
#
#
# Original: buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian
# Stemming: buku referensi pustaka bantu susun tugas teliti
# Lemmatization: buku referensi perpustakaan bantu susun tugas teliti
#
#
# Original: kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu
# Stemming: kalang akademisi manfaat pustaka teliti kembang ilmu
# Lemmatization: kalangan akademisi manfaat perpustakaan teliti kembang ilmu
#
#
# Original: perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku
# Stemming: pustaka milik sistem kelola jaga koleksi buku
# Lemmatization: perpustakaan milik sistem kelola jaga koleksi buku
#
#
# Original: belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja
# Stemming: ajar media elektronik pustaka populer kalang remaja
# Lemmatization: belajar media elektronik perpustakaan populer kalangan remaja
#
#
# Original: perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat
# Stemming: pustaka main peran dukung program literasi masyarakat
# Lemmatization: perpustakaan main peran dukung program literasi masyarakat
#
#
# Original: kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan
# Stemming: kalang profesional akses jurnal artikel ilmiah pustaka
# Lemmatization: kalangan profesional akses jurnal artikel ilmiah perpustakaan
#
#
# Original: membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung
# Stemming: baca majalah koran pustaka wawas unjung
# Lemmatization: baca majalah koran perpustakaan wawas kunjung
#
#
# Original: perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar
# Stemming: pustaka sekolah kali nyaman ajar
# Lemmatization: perpustakaan sekolah kali nyaman belajar
#
#
# Original: kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat
# Stemming: kalang teliti pustaka data referensi akurat
# Lemmatization: kalangan teliti perpustakaan data referensi akurat

# %% [markdown]
# PEMBOBOTAN KATA

# %%
# Fungsi untuk membuat TF-IDF dengan stemming
def tfidf_with_stemming(documents):
    # Preprocessing dengan stemming
    preprocessed_documents = [preprocess_with_stemming(doc) for doc in documents]
    # Buat TF-IDF Vectorizer
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(preprocessed_documents)
    return tfidf_matrix, vectorizer

# %%
# Fungsi untuk membuat TF-IDF dengan lemmatization

def tfidf_with_lemmatization(documents):
    # Preprocessing dengan lemmatization
    preprocessed_documents = [preprocess_with_lemmatization(doc) for doc in documents]
    # Buat TF-IDF Vectorizer
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(preprocessed_documents)
    return tfidf_matrix, vectorizer

# %% [markdown]
# QUERY UNTUK PENCARIAN DOKUMEN

# %%
query = "Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar"

# %% [markdown]
# # SKENARIO 1 : STEMMING VS LEMMATIZATION

# %%
# Scenario 1a: Stemming
print("\nScenario 1a: Using Stemming")
tfidf_stemmed_matrix, tfidf_stemmed_vectorizer = tfidf_with_stemming(documents)

# Preprocess query with stemming
preprocessed_query_stemmed = preprocess_with_stemming(query)
query_vector_stemmed = tfidf_stemmed_vectorizer.transform([preprocessed_query_stemmed])

# Calculate cosine similarities
cosine_similarities_stemmed = cosine_similarity(query_vector_stemmed, tfidf_stemmed_matrix).flatten()

# Rank documents based on similarities
ranked_indices_stemmed = np.argsort(cosine_similarities_stemmed)[::-1]

# Tampilkan hasil
print("Pencarian dengan TF-IDF (Stemming):")
print("Query:", query)
print("\nTop Documents:")

# Perbaikan: definisikan i sebagai counter
for i, idx in enumerate(ranked_indices_stemmed):
    print(f"{i + 1}. Doc {idx + 1} \t (Cosine Similarity: {cosine_similarities_stemmed[idx]:.4f}) \t: {documents[idx]}")
# Out:
# Scenario 1a: Using Stemming
# Pencarian dengan TF-IDF (Stemming):
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8504) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.4717) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.2690) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.2328) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 8 	 (Cosine Similarity: 0.1607) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 6. Doc 20 	 (Cosine Similarity: 0.1607) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 7. Doc 19 	 (Cosine Similarity: 0.1501) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 8. Doc 13 	 (Cosine Similarity: 0.1465) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 9. Doc 2 	 (Cosine Similarity: 0.1416) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 10. Doc 17 	 (Cosine Similarity: 0.1378) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 11. Doc 10 	 (Cosine Similarity: 0.1327) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 12. Doc 9 	 (Cosine Similarity: 0.1305) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1305) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1305) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 11 	 (Cosine Similarity: 0.0838) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 16. Doc 18 	 (Cosine Similarity: 0.0366) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 17. Doc 12 	 (Cosine Similarity: 0.0349) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0336) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 14 	 (Cosine Similarity: 0.0329) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 20. Doc 16 	 (Cosine Similarity: 0.0328) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.

# %%
# Scenario 1b: Lemmatization
print("\nScenario 1b: Using Lemmatization")
tfidf_lemmatized_matrix, tfidf_lemmatized_vectorizer = tfidf_with_lemmatization(documents)

# Preprocess query with lemmatization
preprocessed_query_lemmatized = preprocess_with_lemmatization(query)
query_vector_lemmatized = tfidf_lemmatized_vectorizer.transform([preprocessed_query_lemmatized])

# Calculate cosine similarities
cosine_similarities_lemmatized = cosine_similarity(query_vector_lemmatized, tfidf_lemmatized_matrix).flatten()

# Rank documents based on similarities
ranked_indices_lemmatized = np.argsort(cosine_similarities_lemmatized)[::-1]

# Tampilkan hasil dengan penomoran
print("Pencarian dengan TF-IDF (Lemmatization):")
print("Query:", query)
print("\nTop Documents:")
for i, idx in enumerate(ranked_indices_lemmatized):
    print(f"{i + 1}. Doc {idx + 1} \t (Cosine Similarity: {cosine_similarities_lemmatized[idx]:.4f}) \t: {documents[idx]}")
# Out:
# Scenario 1b: Using Lemmatization
# Pencarian dengan TF-IDF (Lemmatization):
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.2745) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 11 	 (Cosine Similarity: 0.2571) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 4. Doc 18 	 (Cosine Similarity: 0.2311) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 5. Doc 1 	 (Cosine Similarity: 0.2287) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 6. Doc 15 	 (Cosine Similarity: 0.1980) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.1367) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1367) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1276) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 13 	 (Cosine Similarity: 0.1246) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 11. Doc 2 	 (Cosine Similarity: 0.1204) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 17 	 (Cosine Similarity: 0.1172) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 13. Doc 10 	 (Cosine Similarity: 0.1129) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 14. Doc 6 	 (Cosine Similarity: 0.1110) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 5 	 (Cosine Similarity: 0.1110) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 16. Doc 9 	 (Cosine Similarity: 0.1110) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 17. Doc 12 	 (Cosine Similarity: 0.0297) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0286) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 14 	 (Cosine Similarity: 0.0280) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 20. Doc 16 	 (Cosine Similarity: 0.0279) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.

# %% [markdown]
# # SKENARIO 2 : COSINE SIMILARITY VS EUCLIDEAN DISTANCE

# %%
# Scenario 2a: Using Euclidean Distance
print("\nScenario 2a: Using Euclidean Distance")
tfidf_lemmatized_matrix, tfidf_lemmatized_vectorizer = tfidf_with_lemmatization(documents)

# Preprocess query with lemmatization
preprocessed_query_lemmatized = preprocess_with_lemmatization(query)
query_vector_lemmatized = tfidf_lemmatized_vectorizer.transform([preprocessed_query_lemmatized])

# Convert the sparse matrices to dense arrays
tfidf_lemmatized_matrix_dense = tfidf_lemmatized_matrix.toarray()
query_vector_lemmatized_dense = query_vector_lemmatized.toarray()

# Calculate Euclidean distances
euclidean_distances_lemmatized = np.linalg.norm(tfidf_lemmatized_matrix_dense - query_vector_lemmatized_dense, axis=1)

# Rank documents based on Euclidean Distance (nilai lebih kecil lebih baik)
ranked_indices_lemmatized = np.argsort(euclidean_distances_lemmatized)

# Tampilkan hasil dengan penomoran
print("Pencarian dengan TF-IDF (Euclidean Distance):")
print("Query:", query)
print("\nTop Documents:")
for i, idx in enumerate(ranked_indices_lemmatized):
    print(f"{i + 1}. Doc {idx + 1} \t (Euclidean Distance: {euclidean_distances_lemmatized[idx]:.4f}) \t: {documents[idx]}")
# Out:
# Scenario 2a: Using Euclidean Distance
# Pencarian dengan TF-IDF (Euclidean Distance):
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Euclidean Distance: 0.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Euclidean Distance: 1.2046) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 11 	 (Euclidean Distance: 1.2189) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 4. Doc 18 	 (Euclidean Distance: 1.2401) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 5. Doc 1 	 (Euclidean Distance: 1.2420) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 6. Doc 15 	 (Euclidean Distance: 1.2665) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Euclidean Distance: 1.3140) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Euclidean Distance: 1.3140) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Euclidean Distance: 1.3209) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 13 	 (Euclidean Distance: 1.3232) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 11. Doc 2 	 (Euclidean Distance: 1.3264) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 17 	 (Euclidean Distance: 1.3288) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 13. Doc 10 	 (Euclidean Distance: 1.3320) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 14. Doc 9 	 (Euclidean Distance: 1.3334) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 15. Doc 6 	 (Euclidean Distance: 1.3334) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 16. Doc 5 	 (Euclidean Distance: 1.3334) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 17. Doc 12 	 (Euclidean Distance: 1.3931) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Euclidean Distance: 1.3939) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 14 	 (Euclidean Distance: 1.3943) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 20. Doc 16 	 (Euclidean Distance: 1.3943) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.

# %%
# Scenario 2b: Using Cosine Similarity
print("\nScenario 1b: Using Cosine Similarity")
tfidf_lemmatized_matrix, tfidf_lemmatized_vectorizer = tfidf_with_lemmatization(documents)

# Preprocess query with lemmatization
preprocessed_query_lemmatized = preprocess_with_lemmatization(query)
query_vector_lemmatized = tfidf_lemmatized_vectorizer.transform([preprocessed_query_lemmatized])

# Calculate Cosine Similarities
cosine_similarities_lemmatized = cosine_similarity(query_vector_lemmatized, tfidf_lemmatized_matrix).flatten()

# Rank documents based on Cosine Similarity (nilai lebih besar lebih baik)
ranked_indices_lemmatized = np.argsort(cosine_similarities_lemmatized)[::-1]

# Tampilkan hasil dengan penomoran
print("Pencarian dengan TF-IDF (Cosine Similarity):")
print("Query:", query)
print("\nTop Documents:")
for i, idx in enumerate(ranked_indices_lemmatized):
    print(f"{i + 1}. Doc {idx + 1} \t (Cosine Similarity: {cosine_similarities_lemmatized[idx]:.4f}) \t: {documents[idx]}")
# Out:
# Scenario 1b: Using Cosine Similarity
# Pencarian dengan TF-IDF (Cosine Similarity):
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.2745) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 11 	 (Cosine Similarity: 0.2571) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 4. Doc 18 	 (Cosine Similarity: 0.2311) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 5. Doc 1 	 (Cosine Similarity: 0.2287) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 6. Doc 15 	 (Cosine Similarity: 0.1980) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.1367) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1367) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1276) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 13 	 (Cosine Similarity: 0.1246) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 11. Doc 2 	 (Cosine Similarity: 0.1204) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 17 	 (Cosine Similarity: 0.1172) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 13. Doc 10 	 (Cosine Similarity: 0.1129) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 14. Doc 6 	 (Cosine Similarity: 0.1110) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 5 	 (Cosine Similarity: 0.1110) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 16. Doc 9 	 (Cosine Similarity: 0.1110) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 17. Doc 12 	 (Cosine Similarity: 0.0297) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0286) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 14 	 (Cosine Similarity: 0.0280) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 20. Doc 16 	 (Cosine Similarity: 0.0279) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.

# %% [markdown]
# # SKENARIO 3 : VARIASI TF

# %%
# Fungsi untuk menghitung berbagai jenis Term Frequency (TF)
def compute_tf(documents, tf_type):
    tf_matrix = []
    for doc in documents:
        # Preprocess dokumen menggunakan lemmatization
        tokens = preprocess_with_lemmatization(doc)
        token_counts = pd.Series(tokens.split()).value_counts()

        # Hitung jenis TF sesuai dengan tipe yang dipilih
        if tf_type == 'binary':
            tf_vector = (token_counts > 0).astype(int)
        elif tf_type == 'raw_frequency':
            tf_vector = token_counts
        elif tf_type == 'log_normalization':
            tf_vector = 1 + np.log(token_counts)
        elif tf_type == 'double_normalization_0.5':
            max_count = token_counts.max()
            tf_vector = 0.5 + 0.5 * (token_counts / max_count)
        elif tf_type == 'double_normalization_K':
            K = 0.5  # Anda dapat mengubah nilai K sesuai kebutuhan
            max_count = token_counts.max()
            tf_vector = K + (1 - K) * (token_counts / max_count)

        # Tambahkan ke matriks TF
        tf_matrix.append(tf_vector)

    # Kembalikan DataFrame dengan nilai 0 untuk nilai yang hilang (fillna(0))
    return pd.DataFrame(tf_matrix).fillna(0).T

# Fungsi untuk menjalankan TF dan pencarian dokumen
def run_tf_ranking(documents, query, tf_types):
    for tf_type in tf_types:
        print(f"\nScenario: Using TF = {tf_type}")

        # Hitung TF untuk dokumen
        tf_matrix = compute_tf(documents, tf_type)

        # Preprocess query menggunakan lemmatization
        preprocessed_query_tf = preprocess_with_lemmatization(query)
        query_tf = pd.Series(preprocessed_query_tf.split()).value_counts()

        # Buat query vector yang sejajar dengan matriks TF dokumen
        query_tf_vector = pd.Series(query_tf).reindex(tf_matrix.index, fill_value=0).values.reshape(1, -1)

        # Hitung cosine similarity
        cosine_similarities_tf = cosine_similarity(query_tf_vector, tf_matrix.T).flatten()

        # Ranking dokumen berdasarkan cosine similarity
        ranked_indices_tf = np.argsort(cosine_similarities_tf)[::-1]

        # Tampilkan hasil ranking dokumen dengan penomoran
        print(f"Pencarian dengan TF = {tf_type}:")
        print("Query:", query)
        print("\nTop Documents:")
        for i, idx in enumerate(ranked_indices_tf):
            print(f"{i + 1}. Doc {idx + 1} \t (Cosine Similarity: {cosine_similarities_tf[idx]:.4f}) \t: {documents[idx]}")

# Kombinasi berbagai jenis TF
tf_types = ['binary', 'raw_frequency', 'log_normalization', 'double_normalization_0.5', 'double_normalization_K']

# Jalankan ranking dengan semua variasi TF
run_tf_ranking(documents, query, tf_types)
# Out:
# Scenario: Using TF = binary
# Pencarian dengan TF = binary:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = raw_frequency
# Pencarian dengan TF = raw_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = log_normalization
# Pencarian dengan TF = log_normalization:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = double_normalization_0.5
# Pencarian dengan TF = double_normalization_0.5:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = double_normalization_K
# Pencarian dengan TF = double_normalization_K:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.

# %% [markdown]
# # SKENARIO 4 : VARIASI TF-IDF

# %%
# Fungsi untuk menghitung berbagai jenis TF
def compute_tf(documents, tf_type):
    tf_matrix = []
    for doc in documents:
        # Preprocess dokumen menggunakan lemmatization
        tokens = preprocess_with_lemmatization(doc)
        token_counts = pd.Series(tokens.split()).value_counts()

        # Hitung jenis TF sesuai dengan tipe yang dipilih
        if tf_type == 'binary':
            tf_vector = (token_counts > 0).astype(int)
        elif tf_type == 'raw_frequency':
            tf_vector = token_counts
        elif tf_type == 'log_normalization':
            tf_vector = 1 + np.log(token_counts)
        elif tf_type == 'double_normalization_0.5':
            max_count = token_counts.max()
            tf_vector = 0.5 + 0.5 * (token_counts / max_count)
        elif tf_type == 'double_normalization_K':
            K = 0.5  # Anda dapat mengubah nilai K sesuai kebutuhan
            max_count = token_counts.max()
            tf_vector = K + (1 - K) * (token_counts / max_count)

        # Tambahkan ke matriks TF
        tf_matrix.append(tf_vector)

    # Kembalikan DataFrame dengan nilai 0 untuk nilai yang hilang (fillna(0))
    return pd.DataFrame(tf_matrix).fillna(0).T

# Fungsi untuk menghitung berbagai jenis IDF
def compute_idf(documents, idf_type):
    N = len(documents)
    token_df = pd.Series(' '.join(preprocess_with_lemmatization(doc) for doc in documents).split()).value_counts()

    # Hitung jenis IDF sesuai dengan tipe yang dipilih
    if idf_type == 'unary':
        idf_vector = pd.Series(1, index=token_df.index)
    elif idf_type == 'inverse_frequency':
        idf_vector = np.log(N / token_df)
    elif idf_type == 'inv_frequency_smooth':
        idf_vector = np.log(1 + (N / token_df))
    elif idf_type == 'inv_frequency_max':
        max_df = token_df.max()
        idf_vector = np.log(1 + (max_df / token_df))
    elif idf_type == 'probabilistic_inv_frequency':
        idf_vector = np.log((N - token_df) / token_df)

    return idf_vector

# Fungsi untuk menghitung TF-IDF
def compute_tf_idf(documents, tf_type, idf_type):
    tf_matrix = compute_tf(documents, tf_type)
    idf_vector = compute_idf(documents, idf_type)

    # Perkalian elemen-wise antara TF dan IDF
    tf_idf_matrix = tf_matrix.multiply(idf_vector, axis=0)

    return tf_idf_matrix

# Kombinasi berbagai jenis TF dan IDF
tf_types = ['binary', 'raw_frequency', 'log_normalization', 'double_normalization_0.5', 'double_normalization_K']
idf_types = ['unary', 'inverse_frequency', 'inv_frequency_smooth', 'inv_frequency_max', 'probabilistic_inv_frequency']

# Fungsi utama untuk menjalankan kombinasi TF-IDF dan perankingan dokumen
def run_tf_idf_ranking(documents, query, tf_types, idf_types):
    for tf_type in tf_types:
        for idf_type in idf_types:
            print(f"\nScenario: Using TF = {tf_type} and IDF = {idf_type}")

            # Hitung TF-IDF untuk dokumen
            tf_idf_matrix = compute_tf_idf(documents, tf_type, idf_type)

            # Preprocess query menggunakan lemmatization
            preprocessed_query = preprocess_with_lemmatization(query)
            query_tf = pd.Series(preprocessed_query.split()).value_counts()

            # Hitung TF-IDF untuk query dan cosine similarity
            query_tf_vector = pd.Series(query_tf).reindex(tf_idf_matrix.index, fill_value=0).values.reshape(1, -1)
            cosine_similarities = cosine_similarity(query_tf_vector, tf_idf_matrix.T).flatten()

            # Ranking dokumen berdasarkan cosine similarity
            ranked_indices = np.argsort(cosine_similarities)[::-1]

            # Tampilkan hasil ranking dokumen dengan format sesuai keinginan Anda
            print(f"Pencarian dengan TF = {tf_type} dan IDF = {idf_type}:")
            print("Query:", query)
            print("\nTop Documents:")
            for i, idx in enumerate(ranked_indices):
                print(f"{i + 1}. Doc {idx + 1} \t (Cosine Similarity: {cosine_similarities[idx]:.4f}) \t: {documents[idx]}")

# Contoh penggunaan dengan query
run_tf_idf_ranking(documents, query, tf_types, idf_types)
# Out:
# Scenario: Using TF = binary and IDF = unary
# Pencarian dengan TF = binary dan IDF = unary:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = binary and IDF = inverse_frequency
# Pencarian dengan TF = binary dan IDF = inverse_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.7862) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1925) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 7 	 (Cosine Similarity: 0.1880) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 1 	 (Cosine Similarity: 0.1648) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 5. Doc 18 	 (Cosine Similarity: 0.1492) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 6. Doc 15 	 (Cosine Similarity: 0.1217) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.0822) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.0822) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 13 	 (Cosine Similarity: 0.0753) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 10. Doc 19 	 (Cosine Similarity: 0.0683) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 11. Doc 2 	 (Cosine Similarity: 0.0671) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 10 	 (Cosine Similarity: 0.0668) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 13. Doc 17 	 (Cosine Similarity: 0.0667) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 5 	 (Cosine Similarity: 0.0582) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: 0.0582) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: 0.0582) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 12 	 (Cosine Similarity: 0.0039) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0036) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = binary and IDF = inv_frequency_smooth
# Pencarian dengan TF = binary dan IDF = inv_frequency_smooth:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8918) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3354) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3209) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2230) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2161) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2037) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1596) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1596) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1594) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1547) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1464) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1369) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1369) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1369) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1316) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1307) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0522) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0490) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0476) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0471) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = binary and IDF = inv_frequency_max
# Pencarian dengan TF = binary dan IDF = inv_frequency_max:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8892) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3327) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3171) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2216) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2130) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2020) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1575) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1575) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1569) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1524) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1445) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1347) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1347) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1347) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1296) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1289) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0513) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0481) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0467) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0462) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = binary and IDF = probabilistic_inv_frequency
# Pencarian dengan TF = binary dan IDF = probabilistic_inv_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.2113) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1350) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 18 	 (Cosine Similarity: -0.0848) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 4. Doc 17 	 (Cosine Similarity: -0.1633) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 5. Doc 10 	 (Cosine Similarity: -0.1647) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 6. Doc 15 	 (Cosine Similarity: -0.1721) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 13 	 (Cosine Similarity: -0.1822) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 8. Doc 14 	 (Cosine Similarity: -0.1860) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 9. Doc 16 	 (Cosine Similarity: -0.1878) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 10. Doc 4 	 (Cosine Similarity: -0.1936) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 11. Doc 8 	 (Cosine Similarity: -0.1947) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 12. Doc 20 	 (Cosine Similarity: -0.1947) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 13. Doc 12 	 (Cosine Similarity: -0.2067) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 14. Doc 5 	 (Cosine Similarity: -0.2095) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: -0.2095) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: -0.2095) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 2 	 (Cosine Similarity: -0.2367) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 18. Doc 19 	 (Cosine Similarity: -0.2371) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 19. Doc 7 	 (Cosine Similarity: -0.2403) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 20. Doc 1 	 (Cosine Similarity: -0.3853) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
#
# Scenario: Using TF = raw_frequency and IDF = unary
# Pencarian dengan TF = raw_frequency dan IDF = unary:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = raw_frequency and IDF = inverse_frequency
# Pencarian dengan TF = raw_frequency dan IDF = inverse_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.7862) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1925) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 7 	 (Cosine Similarity: 0.1880) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 1 	 (Cosine Similarity: 0.1648) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 5. Doc 18 	 (Cosine Similarity: 0.1492) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 6. Doc 15 	 (Cosine Similarity: 0.1217) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.0822) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.0822) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 13 	 (Cosine Similarity: 0.0753) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 10. Doc 19 	 (Cosine Similarity: 0.0683) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 11. Doc 2 	 (Cosine Similarity: 0.0671) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 10 	 (Cosine Similarity: 0.0668) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 13. Doc 17 	 (Cosine Similarity: 0.0667) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 5 	 (Cosine Similarity: 0.0582) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: 0.0582) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: 0.0582) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 12 	 (Cosine Similarity: 0.0039) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0036) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = raw_frequency and IDF = inv_frequency_smooth
# Pencarian dengan TF = raw_frequency dan IDF = inv_frequency_smooth:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8918) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3354) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3209) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2230) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2161) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2037) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1596) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1596) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1594) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1547) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1464) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1369) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1369) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1369) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1316) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1307) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0522) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0490) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0476) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0471) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = raw_frequency and IDF = inv_frequency_max
# Pencarian dengan TF = raw_frequency dan IDF = inv_frequency_max:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8892) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3327) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3171) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2216) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2130) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2020) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1575) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1575) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1569) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1524) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1445) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1347) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1347) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1347) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1296) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1289) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0513) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0481) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0467) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0462) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = raw_frequency and IDF = probabilistic_inv_frequency
# Pencarian dengan TF = raw_frequency dan IDF = probabilistic_inv_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.2113) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1350) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 18 	 (Cosine Similarity: -0.0848) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 4. Doc 17 	 (Cosine Similarity: -0.1633) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 5. Doc 10 	 (Cosine Similarity: -0.1647) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 6. Doc 15 	 (Cosine Similarity: -0.1721) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 13 	 (Cosine Similarity: -0.1822) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 8. Doc 14 	 (Cosine Similarity: -0.1860) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 9. Doc 16 	 (Cosine Similarity: -0.1878) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 10. Doc 4 	 (Cosine Similarity: -0.1936) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 11. Doc 8 	 (Cosine Similarity: -0.1947) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 12. Doc 20 	 (Cosine Similarity: -0.1947) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 13. Doc 12 	 (Cosine Similarity: -0.2067) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 14. Doc 5 	 (Cosine Similarity: -0.2095) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: -0.2095) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: -0.2095) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 2 	 (Cosine Similarity: -0.2367) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 18. Doc 19 	 (Cosine Similarity: -0.2371) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 19. Doc 7 	 (Cosine Similarity: -0.2403) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 20. Doc 1 	 (Cosine Similarity: -0.3853) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
#
# Scenario: Using TF = log_normalization and IDF = unary
# Pencarian dengan TF = log_normalization dan IDF = unary:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = log_normalization and IDF = inverse_frequency
# Pencarian dengan TF = log_normalization dan IDF = inverse_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.7862) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1925) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 7 	 (Cosine Similarity: 0.1880) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 1 	 (Cosine Similarity: 0.1648) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 5. Doc 18 	 (Cosine Similarity: 0.1492) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 6. Doc 15 	 (Cosine Similarity: 0.1217) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.0822) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.0822) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 13 	 (Cosine Similarity: 0.0753) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 10. Doc 19 	 (Cosine Similarity: 0.0683) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 11. Doc 2 	 (Cosine Similarity: 0.0671) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 10 	 (Cosine Similarity: 0.0668) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 13. Doc 17 	 (Cosine Similarity: 0.0667) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 5 	 (Cosine Similarity: 0.0582) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: 0.0582) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: 0.0582) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 12 	 (Cosine Similarity: 0.0039) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0036) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = log_normalization and IDF = inv_frequency_smooth
# Pencarian dengan TF = log_normalization dan IDF = inv_frequency_smooth:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8918) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3354) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3209) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2230) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2161) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2037) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1596) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1596) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1594) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1547) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1464) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1369) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1369) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1369) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1316) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1307) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0522) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0490) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0476) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0471) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = log_normalization and IDF = inv_frequency_max
# Pencarian dengan TF = log_normalization dan IDF = inv_frequency_max:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8892) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3327) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3171) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2216) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2130) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2020) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1575) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1575) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1569) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1524) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1445) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1347) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1347) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1347) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1296) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1289) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0513) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0481) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0467) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0462) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = log_normalization and IDF = probabilistic_inv_frequency
# Pencarian dengan TF = log_normalization dan IDF = probabilistic_inv_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.2113) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1350) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 18 	 (Cosine Similarity: -0.0848) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 4. Doc 17 	 (Cosine Similarity: -0.1633) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 5. Doc 10 	 (Cosine Similarity: -0.1647) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 6. Doc 15 	 (Cosine Similarity: -0.1721) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 13 	 (Cosine Similarity: -0.1822) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 8. Doc 14 	 (Cosine Similarity: -0.1860) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 9. Doc 16 	 (Cosine Similarity: -0.1878) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 10. Doc 4 	 (Cosine Similarity: -0.1936) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 11. Doc 8 	 (Cosine Similarity: -0.1947) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 12. Doc 20 	 (Cosine Similarity: -0.1947) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 13. Doc 12 	 (Cosine Similarity: -0.2067) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 14. Doc 5 	 (Cosine Similarity: -0.2095) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: -0.2095) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: -0.2095) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 2 	 (Cosine Similarity: -0.2367) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 18. Doc 19 	 (Cosine Similarity: -0.2371) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 19. Doc 7 	 (Cosine Similarity: -0.2403) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 20. Doc 1 	 (Cosine Similarity: -0.3853) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
#
# Scenario: Using TF = double_normalization_0.5 and IDF = unary
# Pencarian dengan TF = double_normalization_0.5 dan IDF = unary:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = double_normalization_0.5 and IDF = inverse_frequency
# Pencarian dengan TF = double_normalization_0.5 dan IDF = inverse_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.7862) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1925) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 7 	 (Cosine Similarity: 0.1880) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 1 	 (Cosine Similarity: 0.1648) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 5. Doc 18 	 (Cosine Similarity: 0.1492) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 6. Doc 15 	 (Cosine Similarity: 0.1217) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.0822) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.0822) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 13 	 (Cosine Similarity: 0.0753) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 10. Doc 19 	 (Cosine Similarity: 0.0683) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 11. Doc 2 	 (Cosine Similarity: 0.0671) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 10 	 (Cosine Similarity: 0.0668) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 13. Doc 17 	 (Cosine Similarity: 0.0667) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 5 	 (Cosine Similarity: 0.0582) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: 0.0582) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: 0.0582) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 12 	 (Cosine Similarity: 0.0039) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0036) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = double_normalization_0.5 and IDF = inv_frequency_smooth
# Pencarian dengan TF = double_normalization_0.5 dan IDF = inv_frequency_smooth:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8918) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3354) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3209) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2230) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2161) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2037) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1596) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1596) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1594) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# ...
# 4. Doc 17 	 (Cosine Similarity: -0.1633) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 5. Doc 10 	 (Cosine Similarity: -0.1647) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 6. Doc 15 	 (Cosine Similarity: -0.1721) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 13 	 (Cosine Similarity: -0.1822) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 8. Doc 14 	 (Cosine Similarity: -0.1860) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 9. Doc 16 	 (Cosine Similarity: -0.1878) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 10. Doc 4 	 (Cosine Similarity: -0.1936) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 11. Doc 8 	 (Cosine Similarity: -0.1947) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 12. Doc 20 	 (Cosine Similarity: -0.1947) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 13. Doc 12 	 (Cosine Similarity: -0.2067) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 14. Doc 5 	 (Cosine Similarity: -0.2095) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: -0.2095) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: -0.2095) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 2 	 (Cosine Similarity: -0.2367) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 18. Doc 19 	 (Cosine Similarity: -0.2371) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 19. Doc 7 	 (Cosine Similarity: -0.2403) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 20. Doc 1 	 (Cosine Similarity: -0.3853) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
#
# Scenario: Using TF = double_normalization_K and IDF = unary
# Pencarian dengan TF = double_normalization_K dan IDF = unary:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 1.0000) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 7 	 (Cosine Similarity: 0.6000) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 3. Doc 1 	 (Cosine Similarity: 0.5164) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 4. Doc 15 	 (Cosine Similarity: 0.5071) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 5. Doc 19 	 (Cosine Similarity: 0.4000) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 6. Doc 2 	 (Cosine Similarity: 0.3651) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 7. Doc 20 	 (Cosine Similarity: 0.3651) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 18 	 (Cosine Similarity: 0.3651) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 9. Doc 8 	 (Cosine Similarity: 0.3651) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 10. Doc 9 	 (Cosine Similarity: 0.3651) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 11. Doc 6 	 (Cosine Similarity: 0.3651) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 12. Doc 5 	 (Cosine Similarity: 0.3651) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 13. Doc 17 	 (Cosine Similarity: 0.3381) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 11 	 (Cosine Similarity: 0.3381) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 15. Doc 13 	 (Cosine Similarity: 0.3381) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 16. Doc 10 	 (Cosine Similarity: 0.3162) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.1690) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 14 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 19. Doc 16 	 (Cosine Similarity: 0.1690) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 4 	 (Cosine Similarity: 0.1690) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
#
# Scenario: Using TF = double_normalization_K and IDF = inverse_frequency
# Pencarian dengan TF = double_normalization_K dan IDF = inverse_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.7862) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1925) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 7 	 (Cosine Similarity: 0.1880) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 1 	 (Cosine Similarity: 0.1648) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 5. Doc 18 	 (Cosine Similarity: 0.1492) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 6. Doc 15 	 (Cosine Similarity: 0.1217) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 20 	 (Cosine Similarity: 0.0822) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.0822) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 13 	 (Cosine Similarity: 0.0753) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 10. Doc 19 	 (Cosine Similarity: 0.0683) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 11. Doc 2 	 (Cosine Similarity: 0.0671) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 12. Doc 10 	 (Cosine Similarity: 0.0668) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 13. Doc 17 	 (Cosine Similarity: 0.0667) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 14. Doc 5 	 (Cosine Similarity: 0.0582) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: 0.0582) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: 0.0582) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 12 	 (Cosine Similarity: 0.0039) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0036) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0035) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = double_normalization_K and IDF = inv_frequency_smooth
# Pencarian dengan TF = double_normalization_K dan IDF = inv_frequency_smooth:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8918) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3354) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3209) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2230) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2161) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2037) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1596) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1596) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1594) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1547) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1464) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1369) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1369) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1369) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1316) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1307) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0522) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0490) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0476) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0471) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = double_normalization_K and IDF = inv_frequency_max
# Pencarian dengan TF = double_normalization_K dan IDF = inv_frequency_max:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.8892) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 1 	 (Cosine Similarity: 0.3327) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
# 3. Doc 7 	 (Cosine Similarity: 0.3171) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 4. Doc 11 	 (Cosine Similarity: 0.2216) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 5. Doc 15 	 (Cosine Similarity: 0.2130) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 6. Doc 18 	 (Cosine Similarity: 0.2020) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 7. Doc 20 	 (Cosine Similarity: 0.1575) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 8. Doc 8 	 (Cosine Similarity: 0.1575) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 9. Doc 19 	 (Cosine Similarity: 0.1569) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 10. Doc 2 	 (Cosine Similarity: 0.1524) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 11. Doc 13 	 (Cosine Similarity: 0.1445) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 12. Doc 9 	 (Cosine Similarity: 0.1347) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 13. Doc 5 	 (Cosine Similarity: 0.1347) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 14. Doc 6 	 (Cosine Similarity: 0.1347) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 15. Doc 17 	 (Cosine Similarity: 0.1296) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 16. Doc 10 	 (Cosine Similarity: 0.1289) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 17. Doc 12 	 (Cosine Similarity: 0.0513) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 18. Doc 4 	 (Cosine Similarity: 0.0481) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 19. Doc 16 	 (Cosine Similarity: 0.0467) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 20. Doc 14 	 (Cosine Similarity: 0.0462) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
#
# Scenario: Using TF = double_normalization_K and IDF = probabilistic_inv_frequency
# Pencarian dengan TF = double_normalization_K dan IDF = probabilistic_inv_frequency:
# Query: Mahasiswa dari berbagai kalangan berkunjung ke perpustakaan untuk belajar
#
# Top Documents:
# 1. Doc 3 	 (Cosine Similarity: 0.2113) 	: Kalangan mahasiswa sering mengunjungi perpustakaan untuk belajar.
# 2. Doc 11 	 (Cosine Similarity: 0.1350) 	: Pustakawan berperan penting dalam membantu pengunjung mencari informasi untuk belajar.
# 3. Doc 18 	 (Cosine Similarity: -0.0848) 	: Membaca majalah dan koran di perpustakaan dapat memberikan wawasan baru bagi pengunjung.
# 4. Doc 17 	 (Cosine Similarity: -0.1633) 	: Kalangan profesional juga dapat mengakses jurnal dan artikel ilmiah di perpustakaan.
# 5. Doc 10 	 (Cosine Similarity: -0.1647) 	: Perpustakaan umum juga mengadakan berbagai acara untuk meningkatkan minat baca kalangan masyarakat.
# 6. Doc 15 	 (Cosine Similarity: -0.1721) 	: Belajar melalui media elektronik di perpustakaan semakin populer di kalangan remaja.
# 7. Doc 13 	 (Cosine Similarity: -0.1822) 	: Kalangan akademisi sering memanfaatkan perpustakaan untuk penelitian dan pengembangan ilmu.
# 8. Doc 14 	 (Cosine Similarity: -0.1860) 	: Perpustakaan memiliki sistem pengelolaan yang baik untuk menjaga koleksi buku.
# 9. Doc 16 	 (Cosine Similarity: -0.1878) 	: Perpustakaan memainkan peran penting dalam mendukung program literasi di masyarakat.
# 10. Doc 4 	 (Cosine Similarity: -0.1936) 	: Koleksi buku di perpustakaan sangat beragam dan mencakup berbagai disiplin ilmu.
# 11. Doc 8 	 (Cosine Similarity: -0.1947) 	: Perpustakaan digital memudahkan akses informasi bagi semua kalangan.
# 12. Doc 20 	 (Cosine Similarity: -0.1947) 	: Kalangan peneliti dapat menggunakan perpustakaan untuk mendapatkan data dan referensi yang akurat.
# 13. Doc 12 	 (Cosine Similarity: -0.2067) 	: Buku referensi di perpustakaan sangat membantu dalam menyusun tugas dan penelitian.
# 14. Doc 5 	 (Cosine Similarity: -0.2095) 	: Belajar mandiri dapat dilakukan dengan memanfaatkan sumber daya perpustakaan.
# 15. Doc 9 	 (Cosine Similarity: -0.2095) 	: Belajar kelompok di perpustakaan dapat meningkatkan pemahaman materi.
# 16. Doc 6 	 (Cosine Similarity: -0.2095) 	: Perpustakaan menyediakan berbagai fasilitas untuk mendukung proses belajar.
# 17. Doc 2 	 (Cosine Similarity: -0.2367) 	: Membaca buku di perpustakaan memberikan pengalaman belajar yang berbeda.
# 18. Doc 19 	 (Cosine Similarity: -0.2371) 	: Perpustakaan sekolah sering kali menjadi tempat yang nyaman untuk belajar.
# 19. Doc 7 	 (Cosine Similarity: -0.2403) 	: Kalangan pelajar di sekolah juga sering menggunakan perpustakaan sebagai tempat belajar.
# 20. Doc 1 	 (Cosine Similarity: -0.3853) 	: Perpustakaan merupakan tempat yang penting untuk belajar dan mendapatkan informasi.
